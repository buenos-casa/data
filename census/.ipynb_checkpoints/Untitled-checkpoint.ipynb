# %%
import pandas as pd
import numpy as np
#import matplotlib as plt

# %%
tmp = pd.read_json("data.json")
# Drop type label
dat = pd.read_json(tmp.properties.to_json())
geometry = pd.read_json(tmp.geometry.to_json())
geometry = geometry.T
dat = dat.T

# %%
dat.head()
print (geometry.head())
df = dat.join(geometry)
df.head()
dat = df
# Out:
#                                          coordinates          type
# 0  [[[[-58.4602255095, -34.5782941566], [-58.4602...  MultiPolygon
# 1  [[[[-58.4600991699, -34.578294646], [-58.45978...  MultiPolygon
# 2  [[[[-58.4573373745, -34.578546656], [-58.45725...  MultiPolygon
# 3  [[[[-58.4605282186, -34.5783], [-58.4605282112...  MultiPolygon
# 4  [[[[-58.4559679927, -34.5789160444], [-58.4553...  MultiPolygon

# %%
dat.columns.unique()
# Out:
# Index(['AREA', 'AREA_2', 'Comune', 'DEPTO', 'FRAC', 'H2819B_p', 'H2819B_q',
#        'H2819C_p', 'H2819C_q', 'INQ_p', 'INQ_q', 'LINK', 'P05_p', 'P05_q',
#        'P19_p', 'P19_q', 'PERIMETER', 'PERIMETRO', 'PROP_p', 'PROP_q', 'PROV',
#        'RADIO', 'RADPAIS_', 'RADPAIS_ID', 'REDCODE', 'TENREG_p', 'TENREG_q',
#        'TIPO', 'V02_p', 'V02_q', 'barrio', 'commune', 'coordinates', 'type'],
#       dtype='object')

# %%
dat.REDCODE.unique()
# Out:
# array([20132502., 20132504., 20132505., ..., 20042109., 20042110.,
#        20042111.])

# %%
def cleanData(df):

    for col in df.columns:
        if '_q' in col or col == 'Comune' or col == 'RADPAIS_ID':
            df[col] = df[col].astype(int)
    
    #First, we define the column names used in all dataframes and their corresponding unified name
    columnNames = {
        'P19_q':'Education Quantile', 'P19_p':'Education Percent',
        'P05_q':'Immigration Quantile', 'P05_p':'Immigration Percent',
        'H2819C_q':'Cellular Quantile', 'H2819C_p':'Cellular Percent',
        'H2819B_q': 'Computer Quantile', 'H2819B_p': 'Computer Percent',
        'V02_q': 'Uninhabited Quantile', 'V02_p': 'Uninhabited Percent',
        'PROP_q':'Owner Quantile', 'PROP_p':'Owner Percent',
        'INQ_q': 'Rent Quantile', 'INQ_p': 'Rent Percent',
        'TENREG_q': 'Regular Quantile', 'TENREG_p': 'Regular Percent',
        'Comune': 'Commune', 'RADPAIS_ID': 'id', 'barrio': 'b_id'
    }

    #Then, delete empty rows, rename the columns and set the index for the Location (Name of the Barrio)
    df = (df.rename(columns=columnNames)
            .set_index('id'))
    
    df = df.drop(['commune','coordinates', 'type', 'PERIMETRO', 'REDCODE', 'DEPTO', 'TIPO', 'RADPAIS_', 'LINK', 'RADIO', 'PROV', 'PERIMETER','FRAC', 'AREA'], axis=1)
    
    return df

# %%
dat = cleanData(dat)

# %%
dat.describe()
# Out:
#              AREA_2      Commune  Computer Percent  Computer Quantile  \
# count  4.796000e+03  4796.000000       4796.000000        4796.000000
# mean   7.388196e+04     8.117181         68.372248           4.396997
# std    2.513253e+05     4.531115         13.137995           2.832926
# min    4.520125e+03     1.000000          3.700000           0.000000
# 25%    2.027947e+04     4.000000         63.700000           2.000000
# 50%    4.097860e+04     8.000000         70.800000           4.000000
# 75%    6.800438e+04    12.000000         76.600000           7.000000
# max    6.379633e+06    15.000000         98.300000           9.000000
#
#        Cellular Percent  Cellular Quantile  Rent Percent  Rent Quantile  \
# count       4796.000000        4796.000000   4796.000000    4796.000000
# mean          87.053357           4.395329     29.620204       4.427231
# std            3.998997           2.856909     11.153711       2.872312
# min           20.000000           0.000000      0.000000       0.000000
# 25%           84.800000           2.000000     22.000000       2.000000
# 50%           87.200000           4.000000     28.400000       4.000000
# 75%           89.400000           7.000000     35.900000       7.000000
# max          100.000000           9.000000     93.000000       9.000000
#
#        Immigration Percent  Immigration Quantile  ...  Education Quantile  \
# count          4796.000000           4796.000000  ...         4796.000000
# mean             13.751731              4.535238  ...            4.338407
# std              11.937043              2.867714  ...            2.843127
# min               2.300000              0.000000  ...            0.000000
# 25%               8.000000              2.000000  ...            2.000000
# 50%              10.500000              5.000000  ...            4.000000
# 75%              14.900000              7.000000  ...            7.000000
# max              97.600000              9.000000  ...            9.000000
#
#           PERIMETRO  Owner Percent  Owner Quantile  Regular Percent  \
# count   4796.000000    4796.000000     4796.000000      4796.000000
# mean   11632.586268      56.625104        4.537948        86.245684
# std     5441.384691      13.168133        2.881464         7.674413
# min     4531.253396       0.000000        0.000000         0.000000
# 25%     7522.360382      48.775000        2.000000        83.800000
# 50%    10021.459665      58.400000        5.000000        87.900000
# 75%    15772.425185      65.900000        7.000000        90.900000
# max    21768.074886      90.700000        9.000000        98.300000
#
#        Regular Quantile  Uninhabited Percent  Uninhabited Quantile  \
# count       4796.000000          4796.000000           4796.000000
# mean           4.451835             3.890742              4.407423
# std            2.847089             3.359906              2.849067
# min            0.000000             0.000000              0.000000
# 25%            2.000000             1.800000              2.000000
# 50%            4.000000             3.200000              4.000000
# 75%            7.000000             5.100000              7.000000
# max            9.000000            83.100000              9.000000
#
#               b_id      commune
# count  4796.000000  4796.000000
# mean     20.291076     8.061093
# std      14.566575     4.532977
# min       0.000000     1.000000
# 25%       7.000000     4.000000
# 50%      19.000000     8.000000
# 75%      32.000000    12.000000
# max      48.000000    15.000000
#
# [8 rows x 21 columns]

# %%
dat.head()
# Out:
#          AREA_2  Commune  Computer Percent  Computer Quantile  \
# id
# 31188  42817.56       13              73.4                  5
# 31242  57245.63       13              78.4                  7
# 31258  30162.88       13              80.1                  8
# 31261  48216.69       15              78.2                  7
# 31270  51368.94       13              76.2                  7
#
#        Cellular Percent  Cellular Quantile  Rent Percent  Rent Quantile  \
# id
# 31188              88.8                  6          25.2              3
# 31242              87.4                  5          29.0              5
# 31258              93.7                  9          19.5              1
# 31261              89.4                  7          29.8              5
# 31270              87.5                  5          24.9              3
#
#        Immigration Percent  Immigration Quantile  ...  Owner Percent  \
# id                                                ...
# 31188                  7.2                     1  ...           63.7
# 31242                  6.7                     1  ...           59.9
# 31258                  5.0                     0  ...           73.8
# 31261                  5.9                     0  ...           60.2
# 31270                  6.9                     1  ...           63.0
#
#        Owner Quantile  Regular Percent  Regular Quantile  Uninhabited Percent  \
# id
# 31188               6             88.8                 5                  6.6
# 31242               5             88.8                 5                  1.6
# 31258               9             93.2                 9                  2.5
# 31261               5             90.0                 6                  3.8
# 31270               6             87.9                 4                  2.0
#
#        Uninhabited Quantile  b_id  commune  \
# id
# 31188                     8  26.0     15.0
# 31242                     2  26.0     15.0
# 31258                     3  26.0     15.0
# 31261                     5  26.0     15.0
# 31270                     2  26.0     15.0
#
#                                              coordinates          type
# id
# 31188  [[[[-58.4602255095, -34.5782941566], [-58.4602...  MultiPolygon
# 31242  [[[[-58.4600991699, -34.578294646], [-58.45978...  MultiPolygon
# 31258  [[[[-58.4573373745, -34.578546656], [-58.45725...  MultiPolygon
# 31261  [[[[-58.4605282186, -34.5783], [-58.4605282112...  MultiPolygon
# 31270  [[[[-58.4559679927, -34.5789160444], [-58.4553...  MultiPolygon
#
# [5 rows x 23 columns]

# %%
sorted(dat.b_id.unique())
# Out:
# array([26., 27.,  6., 29., 12., 11., 31., 33., 45., 19.,  8., 38.,  5.,
#        39., 22., 17., 40., 18., 30., 41., 15., 42., 14., 28.,  4.,  7.,
#        47., 25.,  3., 32., 10.,  9., 46.,  0., 34., 37., 16., 23., 21.,
#        20., 48., 36., 43.,  1., 44., 35.,  2., 24.])

# %%
dat.to_csv('cleaned_data.csv')
